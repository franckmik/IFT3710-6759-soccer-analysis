# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/FootballAnalysis')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%writefile /content/drive/MyDrive/FootballAnalysis/train.py

import torch
from my_module import SoccerEventDataset, SoccerEventClassifier, train_model
from torchvision.transforms import transforms

#root dir
root_dir='/content/drive/MyDrive/FootballAnalysis/train'

#constances
transform= transforms.Compose([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.ToTensor(),
      transforms.Normalize(mean=[.485,.456,.406],std=[.229,.224,.225])
  ])
batch_size=16
num_epochs=10
learning_rate=1e-4
device= torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#full Dataset
full_dataset= SoccerEventDataset(root_dir=root_dir, transform=transform)

#model
model= SoccerEventClassifier().to(device)

if __name__=="__main__":
  train_model(model=model,batch_size=batch_size,num_epochs=num_epochs,
              learning_rate=learning_rate, device=device,
              full_dataset=full_dataset)
# Out:
# Overwriting /content/drive/MyDrive/FootballAnalysis/train.py
